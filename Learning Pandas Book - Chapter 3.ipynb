# %% [markdown]
# ## Chapter 3 - Appending to DataFrame

# %%
import pandas as pd

# %% [markdown]
# Create an empty DataFrame.

# %%
df = pd.DataFrame(columns = ['A', 'B', 'C'])
df
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %% [markdown]
# ### Appending rows to a DataFrame

# %% [markdown]
# Appending a row by a single column value:

# %%
df.loc[0, 'A'] = 1
df
# Out:
#    A    B    C
# 0  1  NaN  NaN

# %% [markdown]
# Appending a row, given a list of values:

# %%
df.loc[1] = [2, 3, 4]
df
# Out:
#    A    B    C
# 0  1  NaN  NaN
# 1  2    3    4

# %% [markdown]
# Appending a row given a dictionary:

# %%
df.loc[2] = {'A': 3, 'C': 9, 'B': 9}
df
# Out:
#    A    B    C
# 0  1  NaN  NaN
# 1  2    3    4
# 2  3    9    9

# %% [markdown]
# The first input in ```.loc[]``` is the index. If you use an existing index, you will overwrite the values in that
# row:

# %%
df.loc[1] = [5, 6, 7]
df
# Out:
#    A    B    C
# 0  1  NaN  NaN
# 1  5    6    7
# 2  3    9    9

# %%
df.loc[0, 'B'] = 8
df
# Out:
#    A  B    C
# 0  1  8  NaN
# 1  5  6    7
# 2  3  9    9

# %% [markdown]
# ### Append a DataFrame to another DataFrame

# %% [markdown]
# Create two DataFrames:

# %%
df1 = pd.DataFrame({'A': ['a1', 'a2'],
 'B': ['b1', 'b2'],
})
df1
# Out:
#     A   B
# 0  a1  b1
# 1  a2  b2

# %%
df2 = pd.DataFrame({'B': ['b1'],
 'C': ['c1'],
})
df2
# Out:
#     B   C
# 0  b1  c1

# %% [markdown]
# The ```append``` method does not change either of the original DataFrames. Instead, it returns a new DataFrame by appending the original two.

# %%
df1.append(df2)
# Out:
# C:\Users\IOZZIA\AppData\Local\conda\conda\envs\tensorflowenv\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#      A   B    C
# 0   a1  b1  NaN
# 1   a2  b2  NaN
# 0  NaN  b1   c1

# %% [markdown]
# You can notice that it is possible to have duplicate indices (0 in this example). To avoid this issue, you may ask Pandas to reindex the new DataFrame for you:

# %%
df1.append(df2, ignore_index = True)
# Out:
#      A   B    C
# 0   a1  b1  NaN
# 1   a2  b2  NaN
# 2  NaN  b1   c1
